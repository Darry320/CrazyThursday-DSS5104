# %%
# %load_ext autoreload
# %autoreload 2
# %env CUDA_VISIBLE_DEVICES=0
import os, sys
import time
sys.path.insert(0, '..')
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import lib
import torch, torch.nn as nn
import torch.nn.functional as F

device = 'cuda' if torch.cuda.is_available() else 'cpu'

experiment_name = 'year_node_shallow'
experiment_name = '{}_{}.{:0>2d}.{:0>2d}_{:0>2d}{:0>2d}'.format(experiment_name, *time.gmtime()[:5])
print("experiment:", experiment_name)
# Out:
# env: CUDA_VISIBLE_DEVICES=0
# Data directory: d:\DSS5104\data
# experiment: year_node_shallow_2025.04.25_0754

# %%
data = lib.Dataset("adult", random_state=999, quantile_transform=True, quantile_noise=1e-3)
in_features = data.X_train.shape[1]

mu, std = data.y_train.mean(), data.y_train.std()
normalize = lambda x: ((x - mu) / std).astype(np.float32)
data.y_train, data.y_valid = map(normalize, [data.y_train, data.y_valid])

print("mean = %.5f, std = %.5f" % (mu, std))
# Out:
# Seeding: 999
# binary classification
# (30162, 14) (30162,)
# (15060, 14) (15060,)
# mean = 0.24892, std = 0.43239

# %%
model = nn.Sequential(
    lib.DenseBlock(in_features, 2048, num_layers=1, tree_dim=3, depth=6, flatten_output=False,
                   choice_function=lib.entmax15, bin_function=lib.entmoid15),
    lib.Lambda(lambda x: x[..., 0].mean(dim=-1)),  # average first channels of every tree
    
).to(device)

with torch.no_grad():
    res = model(torch.as_tensor(data.X_train[:1000], device=device))
    # trigger data-aware init
    
if torch.cuda.device_count() > 1:
    model = nn.DataParallel(model)

# %%
from qhoptim.pyt import QHAdam
optimizer_params = { 'nus':(0.7, 1.0), 'betas':(0.95, 0.998) }

# %%
task_type = 'regression' 
d_out = 1

if task_type == "classification":
    loss_fn = F.binary_cross_entropy_with_logits if d_out == 1 else F.cross_entropy
else:
    loss_fn = F.mse_loss 

trainer = lib.Trainer(
    model=model, loss_function=loss_fn,
    experiment_name=experiment_name,
    warm_start=False,
    Optimizer=QHAdam,
    optimizer_params=optimizer_params,
    verbose=True,
    n_last_checkpoints=5
)

# %%
from tqdm import tqdm
from IPython.display import clear_output
loss_history, mse_history = [], []
best_mse = float('inf')
best_step_mse = 0
early_stopping_rounds = 500
report_frequency = 100

# %%
for batch in lib.iterate_minibatches(data.X_train, data.y_train, batch_size=256, 
                                                shuffle=True, epochs=float('inf')):
    metrics = trainer.train_on_batch(*batch, device=device)
    
    loss_history.append(metrics['loss'])

    if trainer.step % report_frequency == 0:
        trainer.save_checkpoint()
        trainer.average_checkpoints(out_tag='avg')
        trainer.load_checkpoint(tag='avg')
        mse = trainer.evaluate_mse(
            data.X_valid, data.y_valid, device=device, batch_size=1024)

        if mse < best_mse:
            best_mse = mse
            best_step_mse = trainer.step
            trainer.save_checkpoint(tag='best_mse')
        mse_history.append(mse)
        
        trainer.load_checkpoint()  # last
        trainer.remove_old_temp_checkpoints()
        
        clean_loss = [loss.item() if torch.is_tensor(loss) else float(loss) for loss in loss_history]
        clean_mse = [mse.item() if torch.is_tensor(mse) else float(mse) for mse in mse_history]

        clear_output(True)
        plt.figure(figsize=[18, 6])
        plt.subplot(1, 2, 1)
        plt.plot(clean_loss)
        plt.title('Loss')
        plt.grid()
        plt.subplot(1, 2, 2)
        plt.plot(clean_mse)
        plt.title('MSE')
        plt.grid()
        plt.show()
        print("Loss %.5f" % (metrics['loss']))
        print("Val MSE: %0.5f" % (mse))
    if trainer.step > best_step_mse + early_stopping_rounds:
        print('BREAK. There is no improvment for {} steps'.format(early_stopping_rounds))
        print("Best step: ", best_step_mse)
        print("Best Val MSE: %0.5f" % (best_mse))
        break
# Out:
# Loss 0.57933
# Val MSE: 0.65798
# Saved logs/year_node_shallow_2025.04.25_0754\checkpoint_temp_800.pth
# Loaded logs/year_node_shallow_2025.04.25_0754\checkpoint_avg.pth
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 11
#       9 trainer.average_checkpoints(out_tag='avg')
#      10 trainer.load_checkpoint(tag='avg')
# ---> 11 mse = trainer.evaluate_mse(
#      12     data.X_valid, data.y_valid, device=device, batch_size=1024)
#      14 if mse < best_mse:
#      15     best_mse = mse
#
# File d:\DSS5104\node\notebooks\..\lib\trainer.py:146, in Trainer.evaluate_mse(self, X_test, y_test, device, batch_size)
#     144 self.model.train(False)
#     145 with torch.no_grad():
# --> 146     prediction = process_in_chunks(self.model, X_test, batch_size=batch_size)
#     147     prediction = check_numpy(prediction)
#     148     error_rate = ((y_test - prediction) ** 2).mean()
#
# File d:\DSS5104\node\notebooks\..\lib\utils.py:74, in process_in_chunks(function, batch_size, out, *args, **kwargs)
#      72 for i in range(batch_size, total_size, batch_size):
#      73     batch_ix = slice(i, min(i + batch_size, total_size))
# ---> 74     out[batch_ix] = function(*[x[batch_ix] for x in args])
#      75 return out
#
# File d:\anaconda3\envs\NODE\lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File d:\anaconda3\envs\NODE\lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File d:\anaconda3\envs\NODE\lib\site-packages\torch\nn\modules\container.py:240, in Sequential.forward(self, input)
#     238 def forward(self, input):
#     239     for module in self:
# --> 240         input = module(input)
#     241     return input
#
# File d:\anaconda3\envs\NODE\lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File d:\anaconda3\envs\NODE\lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File d:\DSS5104\node\notebooks\..\lib\arch.py:31, in DenseBlock.forward(self, x)
#      29     if self.training and self.input_dropout:
#      30         layer_inp = F.dropout(layer_inp, self.input_dropout)
# ---> 31     h = layer(layer_inp)
#      32     x = torch.cat([x, h], dim=-1)
#      34 outputs = x[..., initial_features:]
#
# File d:\DSS5104\node\notebooks\..\lib\nn_utils.py:221, in ModuleWithInit.__call__(self, *args, **kwargs)
#     219     self._is_initialized_tensor.data[...] = 1
#     220     self._is_initialized_bool = True
# --> 221 return super().__call__(*args, **kwargs)
#
# File d:\anaconda3\envs\NODE\lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File d:\anaconda3\envs\NODE\lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File d:\DSS5104\node\notebooks\..\lib\odst.py:84, in ODST.forward(self, input)
#      81 # new input shape: [batch_size, in_features]
#      83 feature_logits = self.feature_selection_logits
# ---> 84 feature_selectors = self.choice_function(feature_logits, dim=0)
#      85 # ^--[in_features, num_trees, depth]
#      87 feature_values = torch.einsum('bi,ind->bnd', input, feature_selectors)
#
# File d:\DSS5104\node\notebooks\..\lib\nn_utils.py:186, in <lambda>(input, dim)
#     182         grad_input -= q * gppr0
#     183         return grad_input
# --> 186 entmax15 = lambda input, dim=-1: Entmax15Function.apply(input, dim)
#     187 entmoid15 = Entmoid15.apply
#     190 class Lambda(nn.Module):
#
# File d:\anaconda3\envs\NODE\lib\site-packages\torch\autograd\function.py:575, in Function.apply(cls, *args, **kwargs)
#     572 if not torch._C._are_functorch_transforms_active():
#     573     # See NOTE: [functorch vjp and autograd interaction]
#     574     args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 575     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     577 if not is_setup_ctx_defined:
#     578     raise RuntimeError(
#     579         "In order to use an autograd.Function with functorch transforms "
#     580         "(vmap, grad, jvp, jacrev, ...), it must override the setup_context "
#     581         "staticmethod. For more details, please see "
#     582         "https://pytorch.org/docs/main/notes/extending.func.html"
#     583     )
#
# File d:\DSS5104\node\notebooks\..\lib\nn_utils.py:114, in Entmax15Function.forward(ctx, input, dim)
#     110 @staticmethod
#     111 def forward(ctx, input, dim=-1):
#     112     ctx.dim = dim
# --> 114     max_val, _ = input.max(dim=dim, keepdim=True)
#     115     input = input - max_val  # same numerical stability trick as for softmax
#     116     input = input / 2  # divide by 2 to solve actual Entmax
#
# KeyboardInterrupt:

# %%
trainer.load_checkpoint(tag='best_mse')
mse = trainer.evaluate_mse(data.X_test, data.y_test, device=device)
print('Best step: ', trainer.step)
print("Test MSE: %0.5f" % (mse))
# Out:
# Loaded logs/year_node_shallow_2019.08.27_17:32/checkpoint_best_mse.pth
# Best step:  53100
# Test MSE: 0.64902

# %%
mse * std ** 2
# Out:
# 77.51119264257828
